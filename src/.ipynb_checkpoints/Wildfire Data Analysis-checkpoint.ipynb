# %%
import pandas as pd
import numpy as np
import sqlite3
from pprint import pprint
import matplotlib
import matplotlib.pyplot as plt

# %%
# get general info about data (also available on kaggle)
con = sqlite3.connect("../../FPA_FOD_20170508.sqlite")
df = pd.read_sql_query("SELECT name, sql FROM sqlite_master WHERE type='table' ORDER BY name;", conn)
df
# Out:
#                                   name  \
# 0                 ElementaryGeometries
# 1                                Fires
# 2                                  KNN
# 3           NWCG_UnitIDActive_20170109
# 4                         SpatialIndex
# 5                     geometry_columns
# 6                geometry_columns_auth
# 7         geometry_columns_field_infos
# 8          geometry_columns_statistics
# 9                geometry_columns_time
# 10                     idx_Fires_Shape
# 11                idx_Fires_Shape_node
# 12              idx_Fires_Shape_parent
# 13               idx_Fires_Shape_rowid
# 14                     spatial_ref_sys
# 15                 spatial_ref_sys_aux
# 16                  spatialite_history
# 17                  sql_statements_log
# 18                     sqlite_sequence
# 19              views_geometry_columns
# 20         views_geometry_columns_auth
# 21  views_geometry_columns_field_infos
# 22   views_geometry_columns_statistics
# 23              virts_geometry_columns
# 24         virts_geometry_columns_auth
# 25  virts_geometry_columns_field_infos
# 26   virts_geometry_columns_statistics
#
#                                                   sql
# 0   CREATE VIRTUAL TABLE ElementaryGeometries USIN...
# 1   CREATE TABLE Fires (OBJECTID integer primary k...
# 2         CREATE VIRTUAL TABLE KNN USING VirtualKNN()
# 3   CREATE TABLE NWCG_UnitIDActive_20170109 (OBJEC...
# 4   CREATE VIRTUAL TABLE SpatialIndex USING Virtua...
# 5   CREATE TABLE geometry_columns (\nf_table_name ...
# 6   CREATE TABLE geometry_columns_auth (\nf_table_...
# 7   CREATE TABLE geometry_columns_field_infos (\nf...
# 8   CREATE TABLE geometry_columns_statistics (\nf_...
# 9   CREATE TABLE geometry_columns_time (\nf_table_...
# 10  CREATE VIRTUAL TABLE "idx_Fires_Shape" USING r...
# 11  CREATE TABLE "idx_Fires_Shape_node"(nodeno INT...
# 12  CREATE TABLE "idx_Fires_Shape_parent"(nodeno I...
# 13  CREATE TABLE "idx_Fires_Shape_rowid"(rowid INT...
# 14  CREATE TABLE spatial_ref_sys (\nsrid INTEGER N...
# 15  CREATE TABLE spatial_ref_sys_aux (\n\tsrid INT...
# 16  CREATE TABLE spatialite_history (\nevent_id IN...
# 17  CREATE TABLE sql_statements_log (\nid INTEGER ...
# 18             CREATE TABLE sqlite_sequence(name,seq)
# 19  CREATE TABLE views_geometry_columns (\nview_na...
# 20  CREATE TABLE views_geometry_columns_auth (\nvi...
# 21  CREATE TABLE views_geometry_columns_field_info...
# 22  CREATE TABLE views_geometry_columns_statistics...
# 23  CREATE TABLE virts_geometry_columns (\nvirt_na...
# 24  CREATE TABLE virts_geometry_columns_auth (\nvi...
# 25  CREATE TABLE virts_geometry_columns_field_info...
# 26  CREATE TABLE virts_geometry_columns_statistics...

# %%
# make a chart showing number of fires per year
df = pd.read_sql_query("SELECT COUNT(FOD_ID) AS count, FIRE_YEAR FROM Fires GROUP BY FIRE_YEAR ORDER BY FIRE_YEAR", conn)
plt.bar(df['FIRE_YEAR'], df['count'])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Wildfires per Year')
plt.show()

# %%
# list all the possible causes for fires
pd.read_sql_query("SELECT DISTINCT STAT_CAUSE_DESCR, STAT_CAUSE_CODE FROM Fires;", conn)
# Out:
#      STAT_CAUSE_DESCR  STAT_CAUSE_CODE
# 0       Miscellaneous              9.0
# 1           Lightning              1.0
# 2      Debris Burning              5.0
# 3            Campfire              4.0
# 4       Equipment Use              2.0
# 5               Arson              7.0
# 6            Children              8.0
# 7            Railroad              6.0
# 8             Smoking              3.0
# 9           Powerline             11.0
# 10          Structure             12.0
# 11          Fireworks             10.0
# 12  Missing/Undefined             13.0

# %%
# make a chart showing number of naturally caused fires per year
df_natural = pd.read_sql_query("SELECT COUNT(FOD_ID) AS count, FIRE_YEAR FROM Fires WHERE STAT_CAUSE_CODE=1 GROUP BY FIRE_YEAR ORDER BY FIRE_YEAR", conn)
plt.bar(df_natural['FIRE_YEAR'], df_natural['count'])
plt.xlabel('Year')
plt.ylabel('Number of Natual Fires')
plt.title('Number of Natual Wildfires per Year')
plt.show()

# %%
# show % makeup of natual wildfires
assert len(df_natual) == len(df)

plt.scatter(df['FIRE_YEAR'], df_natural['count']*100.0/df['count'])
plt.xlabel('Year')
plt.ylabel('Percent Natual')
plt.title('Percent of Fires that are Natural Per Year')
plt.show()
